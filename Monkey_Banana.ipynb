# %% [markdown]
# <a href="https://colab.research.google.com/github/trisha2k5/CS605PC--AI-LAB-example.html/blob/main/Monkey_Banana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def monkey(state):
  print("Initial state",state)
  state["monkey"]=state["box"]
  state["box"]=state["banana"]
  state["banana"]=state["box"]
  print("Final state",state)
one= input("Enter monkey position")
two= input("Enter  box position")
three= input("Enter banana position")
state={"monkey":one,"box":two,"banana":three}

monkey(state)
# Out:
# Enter monkey position8
# Enter  box position3
# Enter banana position6
# Initial state {'monkey': '8', 'box': '3', 'banana': '6'}
# Final state {'monkey': '3', 'box': '6', 'banana': '6'}

# %%
def monkey(state):
   print("Initial state",state)
   state["monkey"]=state["box"]
   state["box"]=state["banana"]
   state["banana"]=state["box"]
   print("Final state",state)
corner= input("Enter banana position")
left= input("Enter box position")
right= input("Enter monkey position")
state={"banana":corner,"box":left,"monkey":right}
monkey(state)
# Out:
# Enter banana positionleft
# Enter box positioncorner
# Enter monkey positionright
# Initial state {'banana': 'left', 'box': 'corner', 'monkey': 'right'}
# Final state {'banana': 'left', 'box': 'left', 'monkey': 'corner'}
